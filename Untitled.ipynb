# %%
pip install tensorflow
# Out:
# Collecting tensorflow
#   Downloading tensorflow-2.11.0-cp39-cp39-win_amd64.whl (1.9 kB)
# Collecting tensorflow-intel==2.11.0
#   Downloading tensorflow_intel-2.11.0-cp39-cp39-win_amd64.whl (266.3 MB)
# Collecting termcolor>=1.1.0
#   Downloading termcolor-2.1.1-py3-none-any.whl (6.2 kB)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\lenovo\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.42.0)
# Requirement already satisfied: setuptools in c:\users\lenovo\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (61.2.0)
# Requirement already satisfied: packaging in c:\users\lenovo\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (21.3)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\lenovo\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.12.1)
# Collecting tensorflow-estimator<2.12,>=2.11.0
#   Downloading tensorflow_estimator-2.11.0-py2.py3-none-any.whl (439 kB)
# Collecting gast<=0.4.0,>=0.2.1
#   Downloading gast-0.4.0-py3-none-any.whl (9.8 kB)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in c:\users\lenovo\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (3.19.1)
# Collecting tensorflow-io-gcs-filesystem>=0.23.1
#   Downloading tensorflow_io_gcs_filesystem-0.28.0-cp39-cp39-win_amd64.whl (1.5 MB)
# Collecting libclang>=13.0.0
#   Downloading libclang-14.0.6-py2.py3-none-win_amd64.whl (14.2 MB)
# Requirement already satisfied: numpy>=1.20 in c:\users\lenovo\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.21.5)
# Collecting astunparse>=1.6.0
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\lenovo\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (3.6.0)
# Collecting absl-py>=1.0.0
#   Downloading absl_py-1.3.0-py3-none-any.whl (124 kB)
# Collecting opt-einsum>=2.3.2
#   Downloading opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# Requirement already satisfied: six>=1.12.0 in c:\users\lenovo\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.16.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\lenovo\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (4.1.1)
# Collecting flatbuffers>=2.0
#   Downloading flatbuffers-22.12.6-py2.py3-none-any.whl (26 kB)
# Collecting keras<2.12,>=2.11.0
#   Downloading keras-2.11.0-py2.py3-none-any.whl (1.7 MB)
# Collecting tensorboard<2.12,>=2.11
#   Downloading tensorboard-2.11.0-py3-none-any.whl (6.0 MB)
# Collecting google-pasta>=0.1.1
#   Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\lenovo\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.11.0->tensorflow) (0.37.1)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\lenovo\anaconda3\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.27.1)
# Collecting tensorboard-data-server<0.7.0,>=0.6.0
#   Downloading tensorboard_data_server-0.6.1-py3-none-any.whl (2.4 kB)
# Collecting tensorboard-plugin-wit>=1.6.0
#   Downloading tensorboard_plugin_wit-1.8.1-py3-none-any.whl (781 kB)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\lenovo\anaconda3\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.0.3)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\lenovo\anaconda3\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (3.3.4)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\lenovo\anaconda3\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (1.33.0)
# Collecting google-auth-oauthlib<0.5,>=0.4.1
#   Downloading google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\lenovo\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (4.7.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\lenovo\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\users\lenovo\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (4.2.2)
# Collecting requests-oauthlib>=0.7.0
#   Downloading requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\lenovo\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (0.4.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\lenovo\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (1.26.9)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\lenovo\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\lenovo\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lenovo\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2021.10.8)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.2.2-py3-none-any.whl (151 kB)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\lenovo\anaconda3\lib\site-packages (from packaging->tensorflow-intel==2.11.0->tensorflow) (3.0.4)
# Installing collected packages: oauthlib, requests-oauthlib, tensorboard-plugin-wit, tensorboard-data-server, google-auth-oauthlib, absl-py, termcolor, tensorflow-io-gcs-filesystem, tensorflow-estimator, tensorboard, opt-einsum, libclang, keras, google-pasta, gast, flatbuffers, astunparse, tensorflow-intel, tensorflow
# Successfully installed absl-py-1.3.0 astunparse-1.6.3 flatbuffers-22.12.6 gast-0.4.0 google-auth-oauthlib-0.4.6 google-pasta-0.2.0 keras-2.11.0 libclang-14.0.6 oauthlib-3.2.2 opt-einsum-3.3.0 requests-oauthlib-1.3.1 tensorboard-2.11.0 tensorboard-data-server-0.6.1 tensorboard-plugin-wit-1.8.1 tensorflow-2.11.0 tensorflow-estimator-2.11.0 tensorflow-intel-2.11.0 tensorflow-io-gcs-filesystem-0.28.0 termcolor-2.1.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import IPython.display as ipd

# %%
import matplotlib.pyplot as plt
import os
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [43], in <cell line: 3>()
#       1 import matplotlib.pyplot as plt
#       2 import os
# ----> 3 import tensorflow
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
import IPython.display as ipd
filepath = "../AudioProject/urbansound8k/audio/fold1/101415-3-0-2.wav"
ipd.Audio(filepath)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import librosa
import librosa.display
data, sample_rate = librosa.load(filepath)
plt.figure(figsize=(12, 5))
librosa.display.waveshow(data, sr=sample_rate)

# %%
import pandas as pd
metadata = pd.read_csv('../AudioProject/urbansound8k/metadata/UrbanSound8k.csv')
metadata.head(10)
# Out:
#       slice_file_name    fsID      start        end  salience  fold  classID  \
# 0    100032-3-0-0.wav  100032   0.000000   0.317551         1     5        3
# 1  100263-2-0-117.wav  100263  58.500000  62.500000         1     5        2
# 2  100263-2-0-121.wav  100263  60.500000  64.500000         1     5        2
# 3  100263-2-0-126.wav  100263  63.000000  67.000000         1     5        2
# 4  100263-2-0-137.wav  100263  68.500000  72.500000         1     5        2
# 5  100263-2-0-143.wav  100263  71.500000  75.500000         1     5        2
# 6  100263-2-0-161.wav  100263  80.500000  84.500000         1     5        2
# 7    100263-2-0-3.wav  100263   1.500000   5.500000         1     5        2
# 8   100263-2-0-36.wav  100263  18.000000  22.000000         1     5        2
# 9    100648-1-0-0.wav  100648   4.823402   5.471927         2    10        1
#
#               class
# 0          dog_bark
# 1  children_playing
# 2  children_playing
# 3  children_playing
# 4  children_playing
# 5  children_playing
# 6  children_playing
# 7  children_playing
# 8  children_playing
# 9          car_horn

# %%
metadata['class'].value_counts()
# Out:
# dog_bark            1000
# children_playing    1000
# air_conditioner     1000
# street_music        1000
# engine_idling       1000
# jackhammer          1000
# drilling            1000
# siren                929
# car_horn             429
# gun_shot             374
# Name: class, dtype: int64

# %%
import seaborn as sns
plt.figure(figsize=(10, 6))
sns.countplot(metadata['class'])
plt.title("Count of records in each class")
plt.xticks(rotation="vertical")
plt.show()
# Out:
# C:\Users\Lenovo\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
mfccs = librosa.feature.mfcc(y=data, sr=sample_rate, n_mfcc=40)
print(mfccs.shape)
print(mfccs)
# Out:
# (40, 173)
# [[-5.25062866e+02 -5.19553833e+02 -5.18639771e+02 ... -4.35682465e+02
#   -3.85612885e+02 -3.08279907e+02]
#  [ 9.19979095e+00  1.67594376e+01  1.81039009e+01 ...  1.13759224e+02
#    1.47814240e+02  1.36291992e+02]
#  [ 8.83548164e+00  1.57500982e+01  1.72592888e+01 ...  6.42746277e+01
#    4.91346588e+01  3.21460152e+01]
#  ...
#  [ 4.33102250e-01 -3.54089642e+00 -4.83565140e+00 ... -5.26991177e+00
#   -1.60154641e-01  5.95113099e-01]
#  [ 4.45275575e-01 -3.27749443e+00 -4.64729738e+00 ... -3.42241096e+00
#    3.93387961e+00  7.30760217e-01]
#  [ 3.57109100e-01 -2.98991227e+00 -4.41259670e+00 ... -2.67133641e+00
#    2.75666380e+00 -5.42269051e-02]]

# %%
def features_extractor(file):
    #load the file (audio)
    audio, sample_rate = librosa.load(file_name, res_type='kaiser_fast') 
    #we extract mfcc
    mfccs_features = librosa.feature.mfcc(y=audio, sr=sample_rate, n_mfcc=40)
    #in order to find out scaled feature we do mean of transpose of value
    mfccs_scaled_features = np.mean(mfccs_features.T,axis=0)
    return mfccs_scaled_features

# %%
audio_dataset_path="../AudioProject/urbansound8k/audio"

# %%
#Now we ned to extract the featured from all the audio files so we use tqdm
import numpy as np
from tqdm import tqdm
### Now we iterate through every audio file and extract features 
### using Mel-Frequency Cepstral Coefficients
extracted_features=[]
for index_num,row in tqdm(metadata.iterrows()):
    file_name = os.path.join(os.path.abspath(audio_dataset_path),'fold'+str(row["fold"])+'/',str(row["slice_file_name"]))
    final_class_labels=row["class"]
    data=features_extractor(file_name)
    extracted_features.append([data,final_class_labels])
# Out:
# 3555it [03:30, 16.92it/s]C:\Users\Lenovo\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=2048 is too small for input signal of length=1323
#   return f(*args, **kwargs)
# 8324it [07:55, 23.89it/s]C:\Users\Lenovo\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=2048 is too small for input signal of length=1103
#   return f(*args, **kwargs)
# C:\Users\Lenovo\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=2048 is too small for input signal of length=1523
#   return f(*args, **kwargs)
# 8732it [08:17, 17.57it/s]

# %%
### converting extracted_features to Pandas dataframe
extracted_features_df=pd.DataFrame(extracted_features,columns=['feature','class'])
extracted_features_df.head()
# Out:
#                                              feature             class
# 0  [-217.35526, 70.22338, -130.38527, -53.282898,...          dog_bark
# 1  [-424.09818, 109.34077, -52.919525, 60.86475, ...  children_playing
# 2  [-458.79114, 121.38419, -46.520657, 52.00812, ...  children_playing
# 3  [-413.89984, 101.66373, -35.42945, 53.036354, ...  children_playing
# 4  [-446.60352, 113.68541, -52.402206, 60.302044,...  children_playing

# %% [markdown]
# ## Train Test Split

# %%
### Split the dataset into independent and dependent dataset
X=np.array(extracted_features_df['feature'].tolist())
y=np.array(extracted_features_df['class'].tolist())
### Label Encoding -> Label Encoder
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder
labelencoder=LabelEncoder()
y=to_categorical(labelencoder.fit_transform(y))
### Train Test Split
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=0)

# %% [markdown]
# ### Model Creation

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Dropout,Activation,Flatten
from tensorflow.keras.optimizers import Adam
from sklearn import metrics
### No of classes
num_labels=y.shape[1]

# %%
model=Sequential()
###first layer
model.add(Dense(100,input_shape=(40,)))
model.add(Activation('relu'))
model.add(Dropout(0.5))
###second layer
model.add(Dense(200))
model.add(Activation('relu'))
model.add(Dropout(0.5))
###third layer
model.add(Dense(100))
model.add(Activation('relu'))
model.add(Dropout(0.5))
###final layer
model.add(Dense(num_labels))
model.add(Activation('softmax'))

# %%
model.compile(loss='categorical_crossentropy',metrics=['accuracy'],optimizer='adam')

# %%
## Trianing my model
from tensorflow.keras.callbacks import ModelCheckpoint
from datetime import datetime 
num_epochs = 100
num_batch_size = 32
checkpointer = ModelCheckpoint(filepath='./audio_classification.hdf5', 
                               verbose=1, save_best_only=True)
start = datetime.now()
model.fit(X_train, y_train, batch_size=num_batch_size, epochs=num_epochs, validation_data=(X_test, y_test), callbacks=[checkpointer], verbose=1)
duration = datetime.now() - start
print("Training completed in time: ", duration)
# Out:
# Epoch 1/100
# 211/219 [===========================>..] - ETA: 0s - loss: 10.1952 - accuracy: 0.1161
# Epoch 1: val_loss improved from inf to 2.29429, saving model to .\audio_classification.hdf5
# 219/219 [==============================] - 2s 6ms/step - loss: 9.9581 - accuracy: 0.1164 - val_loss: 2.2943 - val_accuracy: 0.1191
# Epoch 2/100
# 213/219 [============================>.] - ETA: 0s - loss: 2.5251 - accuracy: 0.1153
# Epoch 2: val_loss improved from 2.29429 to 2.28143, saving model to .\audio_classification.hdf5
# 219/219 [==============================] - 1s 5ms/step - loss: 2.5215 - accuracy: 0.1155 - val_loss: 2.2814 - val_accuracy: 0.1145
# Epoch 3/100
# 217/219 [============================>.] - ETA: 0s - loss: 2.3318 - accuracy: 0.1420
# Epoch 3: val_loss improved from 2.28143 to 2.23460, saving model to .\audio_classification.hdf5
# 219/219 [==============================] - 1s 5ms/step - loss: 2.3309 - accuracy: 0.1422 - val_loss: 2.2346 - val_accuracy: 0.1362
# Epoch 4/100
# 215/219 [============================>.] - ETA: 0s - loss: 2.2558 - accuracy: 0.1562
# Epoch 4: val_loss improved from 2.23460 to 2.18619, saving model to .\audio_classification.hdf5
# 219/219 [==============================] - 1s 5ms/step - loss: 2.2548 - accuracy: 0.1569 - val_loss: 2.1862 - val_accuracy: 0.1511
# Epoch 5/100
# 211/219 [===========================>..] - ETA: 0s - loss: 2.2140 - accuracy: 0.1604
# Epoch 5: val_loss improved from 2.18619 to 2.13162, saving model to .\audio_classification.hdf5
# 219/219 [==============================] - 1s 5ms/step - loss: 2.2143 - accuracy: 0.1605 - val_loss: 2.1316 - val_accuracy: 0.1786
# Epoch 6/100
# 210/219 [===========================>..] - ETA: 0s - loss: 2.1871 - accuracy: 0.1705
# Epoch 6: val_loss improved from 2.13162 to 2.12228, saving model to .\audio_classification.hdf5
# 219/219 [==============================] - 1s 5ms/step - loss: 2.1862 - accuracy: 0.1708 - val_loss: 2.1223 - val_accuracy: 0.1757
# Epoch 7/100
# 210/219 [===========================>..] - ETA: 0s - loss: 2.1480 - accuracy: 0.1853
# Epoch 7: val_loss improved from 2.12228 to 2.01686, saving model to .\audio_classification.hdf5
# 219/219 [==============================] - 1s 6ms/step - loss: 2.1469 - accuracy: 0.1863 - val_loss: 2.0169 - val_accuracy: 0.2335
# Epoch 8/100
# 212/219 [============================>.] - ETA: 0s - loss: 2.1003 - accuracy: 0.2143
# Epoch 8: val_loss improved from 2.01686 to 1.94681, saving model to .\audio_classification.hdf5
# 219/219 [==============================] - 1s 6ms/step - loss: 2.0988 - accuracy: 0.2142 - val_loss: 1.9468 - val_accuracy: 0.2690
# Epoch 9/100
# 218/219 [============================>.] - ETA: 0s - loss: 2.0594 - accuracy: 0.2245
# Epoch 9: val_loss improved from 1.94681 to 1.92847, saving model to .\audio_classification.hdf5
# 219/219 [==============================] - 1s 5ms/step - loss: 2.0598 - accuracy: 0.2242 - val_loss: 1.9285 - val_accuracy: 0.2868
# Epoch 10/100
# 214/219 [============================>.] - ETA: 0s - loss: 2.0173 - accuracy: 0.2370
# Epoch 10: val_loss improved from 1.92847 to 1.86213, saving model to .\audio_classification.hdf5
# 219/219 [==============================] - 1s 4ms/step - loss: 2.0164 - accuracy: 0.2362 - val_loss: 1.8621 - val_accuracy: 0.2959
# Epoch 11/100
# 210/219 [===========================>..] - ETA: 0s - loss: 1.9799 - accuracy: 0.2525
# Epoch 11: val_loss improved from 1.86213 to 1.83449, saving model to .\audio_classification.hdf5
# 219/219 [==============================] - 1s 4ms/step - loss: 1.9815 - accuracy: 0.2521 - val_loss: 1.8345 - val_accuracy: 0.3383
# Epoch 12/100
# 217/219 [============================>.] - ETA: 0s - loss: 1.9434 - accuracy: 0.2722
# Epoch 12: val_loss improved from 1.83449 to 1.78721, saving model to .\audio_classification.hdf5
# 219/219 [==============================] - 1s 4ms/step - loss: 1.9442 - accuracy: 0.2719 - val_loss: 1.7872 - val_accuracy: 0.3503
# Epoch 13/100
# 207/219 [===========================>..] - ETA: 0s - loss: 1.8938 - accuracy: 0.2909
# Epoch 13: val_loss improved from 1.78721 to 1.74563, saving model to .\audio_classification.hdf5
# 219/219 [==============================] - 1s 5ms/step - loss: 1.8937 - accuracy: 0.2912 - val_loss: 1.7456 - val_accuracy: 0.3726
# Epoch 14/100
# 219/219 [==============================] - ETA: 0s - loss: 1.8583 - accuracy: 0.3051
# Epoch 14: val_loss improved from 1.74563 to 1.66066, saving model to .\audio_classification.hdf5
# 219/219 [==============================] - 1s 6ms/step - loss: 1.8583 - accuracy: 0.3051 - val_loss: 1.6607 - val_accuracy: 0.3990
# Epoch 15/100
# 211/219 [===========================>..] - ETA: 0s - loss: 1.7900 - accuracy: 0.3400
# Epoch 15: val_loss improved from 1.66066 to 1.63021, saving model to .\audio_classification.hdf5
# 219/219 [==============================] - 1s 5ms/step - loss: 1.7899 - accuracy: 0.3416 - val_loss: 1.6302 - val_accuracy: 0.4488
# Epoch 16/100
# 214/219 [============================>.] - ETA: 0s - loss: 1.7655 - accuracy: 0.3588
# Epoch 16: val_loss improved from 1.63021 to 1.56605, saving model to .\audio_classification.hdf5
# 219/219 [==============================] - 1s 4ms/step - loss: 1.7647 - accuracy: 0.3586 - val_loss: 1.5660 - val_accuracy: 0.4740
# Epoch 17/100
# 218/219 [============================>.] - ETA: 0s - loss: 1.7143 - accuracy: 0.3767
# Epoch 17: val_loss improved from 1.56605 to 1.53540, saving model to .\audio_classification.hdf5
# 219/219 [==============================] - 1s 5ms/step - loss: 1.7142 - accuracy: 0.3765 - val_loss: 1.5354 - val_accuracy: 0.4946
# Epoch 18/100
# 218/219 [============================>.] - ETA: 0s - loss: 1.6735 - accuracy: 0.4051
# Epoch 18: val_loss improved from 1.53540 to 1.50156, saving model to .\audio_classification.hdf5
# 219/219 [==============================] - 1s 6ms/step - loss: 1.6735 - accuracy: 0.4052 - val_loss: 1.5016 - val_accuracy: 0.4923
# Epoch 19/100
# 215/219 [============================>.] - ETA: 0s - loss: 1.6456 - accuracy: 0.4084
# Epoch 19: val_loss improved from 1.50156 to 1.47980, saving model to .\audio_classification.hdf5
# 219/219 [==============================] - 1s 6ms/step - loss: 1.6455 - accuracy: 0.4082 - val_loss: 1.4798 - val_accuracy: 0.5243
# Epoch 20/100
# 201/219 [==========================>...] - ETA: 0s - loss: 1.6204 - accuracy: 0.4258
# Epoch 20: val_loss improved from 1.47980 to 1.43897, saving model to .\audio_classification.hdf5
# 219/219 [==============================] - 1s 3ms/step - loss: 1.6178 - accuracy: 0.4248 - val_loss: 1.4390 - val_accuracy: 0.5060
# Epoch 21/100
# 216/219 [============================>.] - ETA: 0s - loss: 1.5820 - accuracy: 0.4372
# Epoch 21: val_loss improved from 1.43897 to 1.39462, saving model to .\audio_classification.hdf5
# 219/219 [==============================] - 1s 4ms/step - loss: 1.5808 - accuracy: 0.4381 - val_loss: 1.3946 - val_accuracy: 0.5186
# Epoch 22/100
# 217/219 [============================>.] - ETA: 0s - loss: 1.5492 - accuracy: 0.4549
# Epoch 22: val_loss improved from 1.39462 to 1.36339, saving model to .\audio_classification.hdf5
# 219/219 [==============================] - 1s 5ms/step - loss: 1.5495 - accuracy: 0.4547 - val_loss: 1.3634 - val_accuracy: 0.5449
# Epoch 23/100
# 212/219 [============================>.] - ETA: 0s - loss: 1.5099 - accuracy: 0.4751
# Epoch 23: val_loss improved from 1.36339 to 1.30722, saving model to .\audio_classification.hdf5
# 219/219 [==============================] - 1s 5ms/step - loss: 1.5126 - accuracy: 0.4736 - val_loss: 1.3072 - val_accuracy: 0.5615
# Epoch 24/100
# 217/219 [============================>.] - ETA: 0s - loss: 1.4970 - accuracy: 0.4741
# Epoch 24: val_loss improved from 1.30722 to 1.30316, saving model to .\audio_classification.hdf5
# 219/219 [==============================] - 1s 5ms/step - loss: 1.4957 - accuracy: 0.4746 - val_loss: 1.3032 - val_accuracy: 0.5701
# Epoch 25/100
# 203/219 [==========================>...] - ETA: 0s - loss: 1.4674 - accuracy: 0.4878
# Epoch 25: val_loss improved from 1.30316 to 1.27843, saving model to .\audio_classification.hdf5
# 219/219 [==============================] - 1s 5ms/step - loss: 1.4628 - accuracy: 0.4895 - val_loss: 1.2784 - val_accuracy: 0.5827
# Epoch 26/100
# 215/219 [============================>.] - ETA: 0s - loss: 1.4289 - accuracy: 0.4971
# Epoch 26: val_loss improved from 1.27843 to 1.26039, saving model to .\audio_classification.hdf5
# 219/219 [==============================] - 1s 6ms/step - loss: 1.4286 - accuracy: 0.4979 - val_loss: 1.2604 - val_accuracy: 0.5718
# Epoch 27/100
# 213/219 [============================>.] - ETA: 0s - loss: 1.4232 - accuracy: 0.5015
# Epoch 27: val_loss improved from 1.26039 to 1.24059, saving model to .\audio_classification.hdf5
# 219/219 [==============================] - 1s 6ms/step - loss: 1.4208 - accuracy: 0.5041 - val_loss: 1.2406 - val_accuracy: 0.5718
# Epoch 28/100
# 211/219 [===========================>..] - ETA: 0s - loss: 1.4032 - accuracy: 0.5142
# Epoch 28: val_loss improved from 1.24059 to 1.24038, saving model to .\audio_classification.hdf5
# 219/219 [==============================] - 1s 5ms/step - loss: 1.4020 - accuracy: 0.5151 - val_loss: 1.2404 - val_accuracy: 0.6050
# Epoch 29/100
# 215/219 [============================>.] - ETA: 0s - loss: 1.3745 - accuracy: 0.5234
# Epoch 29: val_loss improved from 1.24038 to 1.20612, saving model to .\audio_classification.hdf5
# 219/219 [==============================] - 1s 5ms/step - loss: 1.3746 - accuracy: 0.5228 - val_loss: 1.2061 - val_accuracy: 0.6033
# Epoch 30/100
# 217/219 [============================>.] - ETA: 0s - loss: 1.3549 - accuracy: 0.5333
# Epoch 30: val_loss improved from 1.20612 to 1.18013, saving model to .\audio_classification.hdf5
# 219/219 [==============================] - 1s 6ms/step - loss: 1.3531 - accuracy: 0.5340 - val_loss: 1.1801 - val_accuracy: 0.6274
# Epoch 31/100
# 207/219 [===========================>..] - ETA: 0s - loss: 1.3333 - accuracy: 0.5388
# Epoch 31: val_loss improved from 1.18013 to 1.16884, saving model to .\audio_classification.hdf5
# 219/219 [==============================] - 1s 6ms/step - loss: 1.3336 - accuracy: 0.5387 - val_loss: 1.1688 - val_accuracy: 0.6279
# Epoch 32/100
# 209/219 [===========================>..] - ETA: 0s - loss: 1.3149 - accuracy: 0.5393
# Epoch 32: val_loss improved from 1.16884 to 1.16025, saving model to .\audio_classification.hdf5
# 219/219 [==============================] - 1s 5ms/step - loss: 1.3203 - accuracy: 0.5390 - val_loss: 1.1603 - val_accuracy: 0.6182
# Epoch 33/100
# 212/219 [============================>.] - ETA: 0s - loss: 1.3185 - accuracy: 0.5560
# Epoch 33: val_loss improved from 1.16025 to 1.15954, saving model to .\audio_classification.hdf5
# 219/219 [==============================] - 1s 6ms/step - loss: 1.3166 - accuracy: 0.5563 - val_loss: 1.1595 - val_accuracy: 0.6096
# Epoch 34/100
# 215/219 [============================>.] - ETA: 0s - loss: 1.2943 - accuracy: 0.5616
# Epoch 34: val_loss improved from 1.15954 to 1.13716, saving model to .\audio_classification.hdf5
# 219/219 [==============================] - 1s 5ms/step - loss: 1.2928 - accuracy: 0.5613 - val_loss: 1.1372 - val_accuracy: 0.6262
# Epoch 35/100
# 219/219 [==============================] - ETA: 0s - loss: 1.2821 - accuracy: 0.5606
# Epoch 35: val_loss did not improve from 1.13716
# 219/219 [==============================] - 1s 5ms/step - loss: 1.2821 - accuracy: 0.5606 - val_loss: 1.1487 - val_accuracy: 0.6165
# Epoch 36/100
# 215/219 [============================>.] - ETA: 0s - loss: 1.2889 - accuracy: 0.5581
# Epoch 36: val_loss improved from 1.13716 to 1.11373, saving model to .\audio_classification.hdf5
# 219/219 [==============================] - 1s 5ms/step - loss: 1.2876 - accuracy: 0.5593 - val_loss: 1.1137 - val_accuracy: 0.6268
# Epoch 37/100
# 215/219 [============================>.] - ETA: 0s - loss: 1.2477 - accuracy: 0.5749
# Epoch 37: val_loss improved from 1.11373 to 1.09443, saving model to .\audio_classification.hdf5
# 219/219 [==============================] - 1s 5ms/step - loss: 1.2457 - accuracy: 0.5758 - val_loss: 1.0944 - val_accuracy: 0.6491
# Epoch 38/100
# 206/219 [===========================>..] - ETA: 0s - loss: 1.2496 - accuracy: 0.5623
# Epoch 38: val_loss did not improve from 1.09443
# 219/219 [==============================] - 1s 5ms/step - loss: 1.2504 - accuracy: 0.5635 - val_loss: 1.1170 - val_accuracy: 0.6262
# Epoch 39/100
# 213/219 [============================>.] - ETA: 0s - loss: 1.2384 - accuracy: 0.5767
# Epoch 39: val_loss improved from 1.09443 to 1.06723, saving model to .\audio_classification.hdf5
# 219/219 [==============================] - 1s 5ms/step - loss: 1.2435 - accuracy: 0.5759 - val_loss: 1.0672 - val_accuracy: 0.6463
# Epoch 40/100
# 208/219 [===========================>..] - ETA: 0s - loss: 1.2253 - accuracy: 0.5754
# Epoch 40: val_loss did not improve from 1.06723
# 219/219 [==============================] - 1s 5ms/step - loss: 1.2307 - accuracy: 0.5735 - val_loss: 1.0850 - val_accuracy: 0.6394
# Epoch 41/100
# 208/219 [===========================>..] - ETA: 0s - loss: 1.2182 - accuracy: 0.5849
# Epoch 41: val_loss improved from 1.06723 to 1.05613, saving model to .\audio_classification.hdf5
# 219/219 [==============================] - 1s 5ms/step - loss: 1.2186 - accuracy: 0.5868 - val_loss: 1.0561 - val_accuracy: 0.6508
# Epoch 42/100
# 216/219 [============================>.] - ETA: 0s - loss: 1.2361 - accuracy: 0.5770
# Epoch 42: val_loss improved from 1.05613 to 1.04995, saving model to .\audio_classification.hdf5
# 219/219 [==============================] - 1s 5ms/step - loss: 1.2349 - accuracy: 0.5770 - val_loss: 1.0499 - val_accuracy: 0.6548
# Epoch 43/100
# 211/219 [===========================>..] - ETA: 0s - loss: 1.2176 - accuracy: 0.5906
# Epoch 43: val_loss improved from 1.04995 to 1.04289, saving model to .\audio_classification.hdf5
# 219/219 [==============================] - 1s 5ms/step - loss: 1.2203 - accuracy: 0.5908 - val_loss: 1.0429 - val_accuracy: 0.6560
# Epoch 44/100
# 213/219 [============================>.] - ETA: 0s - loss: 1.2130 - accuracy: 0.5893
# Epoch 44: val_loss did not improve from 1.04289
# 219/219 [==============================] - 1s 5ms/step - loss: 1.2105 - accuracy: 0.5897 - val_loss: 1.0495 - val_accuracy: 0.6651
# Epoch 45/100
# 215/219 [============================>.] - ETA: 0s - loss: 1.2097 - accuracy: 0.5922
# Epoch 45: val_loss did not improve from 1.04289
# 219/219 [==============================] - 1s 5ms/step - loss: 1.2090 - accuracy: 0.5924 - val_loss: 1.0451 - val_accuracy: 0.6634
# Epoch 46/100
# 208/219 [===========================>..] - ETA: 0s - loss: 1.2184 - accuracy: 0.5886
# Epoch 46: val_loss improved from 1.04289 to 1.02521, saving model to .\audio_classification.hdf5
# 219/219 [==============================] - 1s 5ms/step - loss: 1.2094 - accuracy: 0.5897 - val_loss: 1.0252 - val_accuracy: 0.6566
# Epoch 47/100
# 218/219 [============================>.] - ETA: 0s - loss: 1.1744 - accuracy: 0.5956
# Epoch 47: val_loss improved from 1.02521 to 1.02047, saving model to .\audio_classification.hdf5
# 219/219 [==============================] - 1s 5ms/step - loss: 1.1753 - accuracy: 0.5954 - val_loss: 1.0205 - val_accuracy: 0.6686
# Epoch 48/100
# 213/219 [============================>.] - ETA: 0s - loss: 1.1459 - accuracy: 0.6093
# Epoch 48: val_loss improved from 1.02047 to 0.98163, saving model to .\audio_classification.hdf5
# 219/219 [==============================] - 1s 6ms/step - loss: 1.1481 - accuracy: 0.6092 - val_loss: 0.9816 - val_accuracy: 0.6823
# Epoch 49/100
# 212/219 [============================>.] - ETA: 0s - loss: 1.1777 - accuracy: 0.5980
# Epoch 49: val_loss did not improve from 0.98163
# 219/219 [==============================] - 1s 5ms/step - loss: 1.1810 - accuracy: 0.5977 - val_loss: 0.9981 - val_accuracy: 0.6691
# Epoch 50/100
# 215/219 [============================>.] - ETA: 0s - loss: 1.1482 - accuracy: 0.6096
# Epoch 50: val_loss improved from 0.98163 to 0.98037, saving model to .\audio_classification.hdf5
# 219/219 [==============================] - 1s 6ms/step - loss: 1.1470 - accuracy: 0.6100 - val_loss: 0.9804 - val_accuracy: 0.6852
# Epoch 51/100
# 219/219 [==============================] - ETA: 0s - loss: 1.1531 - accuracy: 0.6062
# Epoch 51: val_loss did not improve from 0.98037
# 219/219 [==============================] - 1s 6ms/step - loss: 1.1531 - accuracy: 0.6062 - val_loss: 0.9978 - val_accuracy: 0.6600
# Epoch 52/100
# 209/219 [===========================>..] - ETA: 0s - loss: 1.1497 - accuracy: 0.6096
# Epoch 52: val_loss improved from 0.98037 to 0.96951, saving model to .\audio_classification.hdf5
# 219/219 [==============================] - 1s 6ms/step - loss: 1.1541 - accuracy: 0.6083 - val_loss: 0.9695 - val_accuracy: 0.6892
# Epoch 53/100
# 213/219 [============================>.] - ETA: 0s - loss: 1.1388 - accuracy: 0.6156
# Epoch 53: val_loss did not improve from 0.96951
# 219/219 [==============================] - 1s 5ms/step - loss: 1.1396 - accuracy: 0.6160 - val_loss: 0.9735 - val_accuracy: 0.6903
# Epoch 54/100
# 218/219 [============================>.] - ETA: 0s - loss: 1.1346 - accuracy: 0.6137
# Epoch 54: val_loss improved from 0.96951 to 0.95987, saving model to .\audio_classification.hdf5
# 219/219 [==============================] - 1s 6ms/step - loss: 1.1351 - accuracy: 0.6136 - val_loss: 0.9599 - val_accuracy: 0.6875
# Epoch 55/100
# 214/219 [============================>.] - ETA: 0s - loss: 1.1232 - accuracy: 0.6268
# Epoch 55: val_loss improved from 0.95987 to 0.93993, saving model to .\audio_classification.hdf5
# 219/219 [==============================] - 1s 6ms/step - loss: 1.1272 - accuracy: 0.6259 - val_loss: 0.9399 - val_accuracy: 0.6932
# Epoch 56/100
# 211/219 [===========================>..] - ETA: 0s - loss: 1.1317 - accuracy: 0.6188
# Epoch 56: val_loss did not improve from 0.93993
# 219/219 [==============================] - 1s 5ms/step - loss: 1.1313 - accuracy: 0.6195 - val_loss: 0.9567 - val_accuracy: 0.6995
# Epoch 57/100
# 214/219 [============================>.] - ETA: 0s - loss: 1.1346 - accuracy: 0.6148
# Epoch 57: val_loss did not improve from 0.93993
# 219/219 [==============================] - 1s 5ms/step - loss: 1.1333 - accuracy: 0.6157 - val_loss: 0.9547 - val_accuracy: 0.6961
# Epoch 58/100
# 208/219 [===========================>..] - ETA: 0s - loss: 1.1245 - accuracy: 0.6227
# Epoch 58: val_loss improved from 0.93993 to 0.92719, saving model to .\audio_classification.hdf5
# 219/219 [==============================] - 1s 5ms/step - loss: 1.1251 - accuracy: 0.6209 - val_loss: 0.9272 - val_accuracy: 0.6949
# Epoch 59/100
# 210/219 [===========================>..] - ETA: 0s - loss: 1.0990 - accuracy: 0.6262
# Epoch 59: val_loss improved from 0.92719 to 0.92571, saving model to .\audio_classification.hdf5
# 219/219 [==============================] - 1s 5ms/step - loss: 1.1014 - accuracy: 0.6249 - val_loss: 0.9257 - val_accuracy: 0.7167
# Epoch 60/100
# 219/219 [==============================] - ETA: 0s - loss: 1.0830 - accuracy: 0.6304
# Epoch 60: val_loss did not improve from 0.92571
# 219/219 [==============================] - 1s 5ms/step - loss: 1.0830 - accuracy: 0.6304 - val_loss: 0.9271 - val_accuracy: 0.7029
# Epoch 61/100
# 213/219 [============================>.] - ETA: 0s - loss: 1.0946 - accuracy: 0.6263
# Epoch 61: val_loss did not improve from 0.92571
# 219/219 [==============================] - 1s 4ms/step - loss: 1.0951 - accuracy: 0.6262 - val_loss: 0.9498 - val_accuracy: 0.6863
# Epoch 62/100
# 212/219 [============================>.] - ETA: 0s - loss: 1.0857 - accuracy: 0.6256
# Epoch 62: val_loss improved from 0.92571 to 0.91254, saving model to .\audio_classification.hdf5
# 219/219 [==============================] - 1s 5ms/step - loss: 1.0840 - accuracy: 0.6263 - val_loss: 0.9125 - val_accuracy: 0.7058
# Epoch 63/100
# 212/219 [============================>.] - ETA: 0s - loss: 1.0849 - accuracy: 0.6306
# Epoch 63: val_loss did not improve from 0.91254
# 219/219 [==============================] - 1s 5ms/step - loss: 1.0904 - accuracy: 0.6298 - val_loss: 0.9141 - val_accuracy: 0.7069
# Epoch 64/100
# 210/219 [===========================>..] - ETA: 0s - loss: 1.0964 - accuracy: 0.6317
# Epoch 64: val_loss improved from 0.91254 to 0.91151, saving model to .\audio_classification.hdf5
# 219/219 [==============================] - 1s 6ms/step - loss: 1.0931 - accuracy: 0.6325 - val_loss: 0.9115 - val_accuracy: 0.7086
# Epoch 65/100
# 216/219 [============================>.] - ETA: 0s - loss: 1.0940 - accuracy: 0.6256
# Epoch 65: val_loss did not improve from 0.91151
# 219/219 [==============================] - 1s 5ms/step - loss: 1.0943 - accuracy: 0.6253 - val_loss: 0.9168 - val_accuracy: 0.6983
# Epoch 66/100
# 215/219 [============================>.] - ETA: 0s - loss: 1.0919 - accuracy: 0.6369
# Epoch 66: val_loss did not improve from 0.91151
# 219/219 [==============================] - 1s 4ms/step - loss: 1.0940 - accuracy: 0.6361 - val_loss: 0.9146 - val_accuracy: 0.7064
# Epoch 67/100
# 214/219 [============================>.] - ETA: 0s - loss: 1.0922 - accuracy: 0.6384
# Epoch 67: val_loss improved from 0.91151 to 0.88939, saving model to .\audio_classification.hdf5
# 219/219 [==============================] - 1s 4ms/step - loss: 1.0945 - accuracy: 0.6392 - val_loss: 0.8894 - val_accuracy: 0.7144
# Epoch 68/100
# 216/219 [============================>.] - ETA: 0s - loss: 1.0873 - accuracy: 0.6324
# Epoch 68: val_loss improved from 0.88939 to 0.87988, saving model to .\audio_classification.hdf5
# 219/219 [==============================] - 1s 6ms/step - loss: 1.0864 - accuracy: 0.6324 - val_loss: 0.8799 - val_accuracy: 0.7184
# Epoch 69/100
# 213/219 [============================>.] - ETA: 0s - loss: 1.0524 - accuracy: 0.6480
# Epoch 69: val_loss improved from 0.87988 to 0.87435, saving model to .\audio_classification.hdf5
# 219/219 [==============================] - 1s 5ms/step - loss: 1.0518 - accuracy: 0.6475 - val_loss: 0.8743 - val_accuracy: 0.7207
# Epoch 70/100
# 219/219 [==============================] - ETA: 0s - loss: 1.0645 - accuracy: 0.6394
# Epoch 70: val_loss improved from 0.87435 to 0.86453, saving model to .\audio_classification.hdf5
# 219/219 [==============================] - 1s 6ms/step - loss: 1.0645 - accuracy: 0.6394 - val_loss: 0.8645 - val_accuracy: 0.7224
# Epoch 71/100
# 215/219 [============================>.] - ETA: 0s - loss: 1.0966 - accuracy: 0.6387
# Epoch 71: val_loss did not improve from 0.86453
# 219/219 [==============================] - 1s 5ms/step - loss: 1.0956 - accuracy: 0.6392 - val_loss: 0.9083 - val_accuracy: 0.7144
# Epoch 72/100
# 217/219 [============================>.] - ETA: 0s - loss: 1.0494 - accuracy: 0.6442
# Epoch 72: val_loss did not improve from 0.86453
# 219/219 [==============================] - 1s 5ms/step - loss: 1.0495 - accuracy: 0.6441 - val_loss: 0.8658 - val_accuracy: 0.7144
# Epoch 73/100
# 214/219 [============================>.] - ETA: 0s - loss: 1.0687 - accuracy: 0.6377
# Epoch 73: val_loss did not improve from 0.86453
# 219/219 [==============================] - 1s 5ms/step - loss: 1.0668 - accuracy: 0.6385 - val_loss: 0.8710 - val_accuracy: 0.7138
# Epoch 74/100
# 217/219 [============================>.] - ETA: 0s - loss: 1.0775 - accuracy: 0.6398
# Epoch 74: val_loss did not improve from 0.86453
# 219/219 [==============================] - 1s 5ms/step - loss: 1.0783 - accuracy: 0.6394 - val_loss: 0.8977 - val_accuracy: 0.7046
# Epoch 75/100
# 217/219 [============================>.] - ETA: 0s - loss: 1.0688 - accuracy: 0.6380
# Epoch 75: val_loss did not improve from 0.86453
# 219/219 [==============================] - 1s 6ms/step - loss: 1.0681 - accuracy: 0.6378 - val_loss: 0.8686 - val_accuracy: 0.7172
# Epoch 76/100
# 213/219 [============================>.] - ETA: 0s - loss: 1.0545 - accuracy: 0.6414
# Epoch 76: val_loss improved from 0.86453 to 0.84110, saving model to .\audio_classification.hdf5
# 219/219 [==============================] - 1s 6ms/step - loss: 1.0524 - accuracy: 0.6425 - val_loss: 0.8411 - val_accuracy: 0.7281
# Epoch 77/100
# 217/219 [============================>.] - ETA: 0s - loss: 1.0609 - accuracy: 0.6436
# Epoch 77: val_loss did not improve from 0.84110
# 219/219 [==============================] - 1s 5ms/step - loss: 1.0593 - accuracy: 0.6441 - val_loss: 0.8461 - val_accuracy: 0.7355
# Epoch 78/100
# 211/219 [===========================>..] - ETA: 0s - loss: 1.0626 - accuracy: 0.6440
# Epoch 78: val_loss did not improve from 0.84110
# 219/219 [==============================] - 1s 5ms/step - loss: 1.0585 - accuracy: 0.6460 - val_loss: 0.8620 - val_accuracy: 0.7247
# Epoch 79/100
# 218/219 [============================>.] - ETA: 0s - loss: 1.0504 - accuracy: 0.6456
# Epoch 79: val_loss did not improve from 0.84110
# 219/219 [==============================] - 1s 6ms/step - loss: 1.0506 - accuracy: 0.6454 - val_loss: 0.8709 - val_accuracy: 0.7098
# Epoch 80/100
# 213/219 [============================>.] - ETA: 0s - loss: 1.0511 - accuracy: 0.6457
# Epoch 80: val_loss did not improve from 0.84110
# 219/219 [==============================] - 1s 5ms/step - loss: 1.0499 - accuracy: 0.6461 - val_loss: 0.8569 - val_accuracy: 0.7287
# Epoch 81/100
# 210/219 [===========================>..] - ETA: 0s - loss: 1.0392 - accuracy: 0.6461
# Epoch 81: val_loss did not improve from 0.84110
# 219/219 [==============================] - 1s 5ms/step - loss: 1.0425 - accuracy: 0.6460 - val_loss: 0.8504 - val_accuracy: 0.7212
# Epoch 82/100
# 219/219 [==============================] - ETA: 0s - loss: 1.0544 - accuracy: 0.6401
# Epoch 82: val_loss did not improve from 0.84110
# 219/219 [==============================] - 1s 5ms/step - loss: 1.0544 - accuracy: 0.6401 - val_loss: 0.8456 - val_accuracy: 0.7252
# Epoch 83/100
# 218/219 [============================>.] - ETA: 0s - loss: 1.0561 - accuracy: 0.6455
# Epoch 83: val_loss did not improve from 0.84110
# 219/219 [==============================] - 1s 5ms/step - loss: 1.0571 - accuracy: 0.6451 - val_loss: 0.8856 - val_accuracy: 0.7247
# Epoch 84/100
# 214/219 [============================>.] - ETA: 0s - loss: 1.0342 - accuracy: 0.6522
# Epoch 84: val_loss did not improve from 0.84110
# 219/219 [==============================] - 1s 5ms/step - loss: 1.0353 - accuracy: 0.6513 - val_loss: 0.8420 - val_accuracy: 0.7270
# Epoch 85/100
# 214/219 [============================>.] - ETA: 0s - loss: 1.0142 - accuracy: 0.6606
# Epoch 85: val_loss improved from 0.84110 to 0.82637, saving model to .\audio_classification.hdf5
# 219/219 [==============================] - 1s 5ms/step - loss: 1.0180 - accuracy: 0.6590 - val_loss: 0.8264 - val_accuracy: 0.7367
# Epoch 86/100
# 203/219 [==========================>...] - ETA: 0s - loss: 1.0172 - accuracy: 0.6586
# Epoch 86: val_loss did not improve from 0.82637
# 219/219 [==============================] - 1s 5ms/step - loss: 1.0193 - accuracy: 0.6587 - val_loss: 0.8406 - val_accuracy: 0.7367
# Epoch 87/100
# 218/219 [============================>.] - ETA: 0s - loss: 1.0148 - accuracy: 0.6600
# Epoch 87: val_loss did not improve from 0.82637
# 219/219 [==============================] - 1s 4ms/step - loss: 1.0144 - accuracy: 0.6603 - val_loss: 0.8303 - val_accuracy: 0.7361
# Epoch 88/100
# 212/219 [============================>.] - ETA: 0s - loss: 1.0176 - accuracy: 0.6521
# Epoch 88: val_loss did not improve from 0.82637
# 219/219 [==============================] - 1s 5ms/step - loss: 1.0224 - accuracy: 0.6505 - val_loss: 0.8513 - val_accuracy: 0.7207
# Epoch 89/100
# 206/219 [===========================>..] - ETA: 0s - loss: 1.0149 - accuracy: 0.6506
# Epoch 89: val_loss improved from 0.82637 to 0.80556, saving model to .\audio_classification.hdf5
# 219/219 [==============================] - 1s 4ms/step - loss: 1.0130 - accuracy: 0.6508 - val_loss: 0.8056 - val_accuracy: 0.7378
# Epoch 90/100
# 214/219 [============================>.] - ETA: 0s - loss: 1.0076 - accuracy: 0.6596
# Epoch 90: val_loss did not improve from 0.80556
# 219/219 [==============================] - 1s 3ms/step - loss: 1.0062 - accuracy: 0.6588 - val_loss: 0.8113 - val_accuracy: 0.7407
# Epoch 91/100
# 211/219 [===========================>..] - ETA: 0s - loss: 1.0294 - accuracy: 0.6521
# Epoch 91: val_loss did not improve from 0.80556
# 219/219 [==============================] - 1s 5ms/step - loss: 1.0375 - accuracy: 0.6514 - val_loss: 0.8500 - val_accuracy: 0.7224
# Epoch 92/100
# 212/219 [============================>.] - ETA: 0s - loss: 0.9987 - accuracy: 0.6586
# Epoch 92: val_loss improved from 0.80556 to 0.80510, saving model to .\audio_classification.hdf5
# 219/219 [==============================] - 1s 3ms/step - loss: 0.9981 - accuracy: 0.6587 - val_loss: 0.8051 - val_accuracy: 0.7441
# Epoch 93/100
# 217/219 [============================>.] - ETA: 0s - loss: 1.0032 - accuracy: 0.6593
# Epoch 93: val_loss did not improve from 0.80510
# 219/219 [==============================] - 1s 3ms/step - loss: 1.0029 - accuracy: 0.6594 - val_loss: 0.8126 - val_accuracy: 0.7367
# Epoch 94/100
# 203/219 [==========================>...] - ETA: 0s - loss: 0.9980 - accuracy: 0.6636
# Epoch 94: val_loss did not improve from 0.80510
# 219/219 [==============================] - 1s 3ms/step - loss: 1.0022 - accuracy: 0.6593 - val_loss: 0.8396 - val_accuracy: 0.7281
# Epoch 95/100
# 216/219 [============================>.] - ETA: 0s - loss: 1.0304 - accuracy: 0.6525
# Epoch 95: val_loss did not improve from 0.80510
# 219/219 [==============================] - 1s 4ms/step - loss: 1.0308 - accuracy: 0.6530 - val_loss: 0.8470 - val_accuracy: 0.7344
# Epoch 96/100
# 211/219 [===========================>..] - ETA: 0s - loss: 1.0110 - accuracy: 0.6613
# Epoch 96: val_loss did not improve from 0.80510
# 219/219 [==============================] - 1s 6ms/step - loss: 1.0128 - accuracy: 0.6597 - val_loss: 0.8284 - val_accuracy: 0.7189
# Epoch 97/100
# 216/219 [============================>.] - ETA: 0s - loss: 1.0087 - accuracy: 0.6662
# Epoch 97: val_loss did not improve from 0.80510
# 219/219 [==============================] - 1s 5ms/step - loss: 1.0060 - accuracy: 0.6671 - val_loss: 0.8157 - val_accuracy: 0.7367
# Epoch 98/100
# 211/219 [===========================>..] - ETA: 0s - loss: 1.0030 - accuracy: 0.6628
# Epoch 98: val_loss improved from 0.80510 to 0.80473, saving model to .\audio_classification.hdf5
# 219/219 [==============================] - 1s 5ms/step - loss: 1.0062 - accuracy: 0.6616 - val_loss: 0.8047 - val_accuracy: 0.7401
# Epoch 99/100
# 215/219 [============================>.] - ETA: 0s - loss: 0.9940 - accuracy: 0.6642
# Epoch 99: val_loss improved from 0.80473 to 0.80434, saving model to .\audio_classification.hdf5
# 219/219 [==============================] - 1s 5ms/step - loss: 0.9960 - accuracy: 0.6643 - val_loss: 0.8043 - val_accuracy: 0.7413
# Epoch 100/100
# 213/219 [============================>.] - ETA: 0s - loss: 0.9832 - accuracy: 0.6614
# Epoch 100: val_loss improved from 0.80434 to 0.79216, saving model to .\audio_classification.hdf5
# 219/219 [==============================] - 1s 6ms/step - loss: 0.9823 - accuracy: 0.6620 - val_loss: 0.7922 - val_accuracy: 0.7459
# Training completed in time:  0:01:52.569626

# %%
test_accuracy=model.evaluate(X_test,y_test,verbose=0)
print(test_accuracy[1])
# Out:
# 0.7458500266075134

# %%
#model.predict_classes(X_test)
predict_x=model.predict(X_test) 
classes_x=np.argmax(predict_x,axis=1)
print(classes_x)
# Out:
# 55/55 [==============================] - 0s 2ms/step
# [5 3 4 ... 1 2 2]

# %%
filename="../AudioProject/urbansound8k/audio/fold10/100648-1-1-0.wav"
#preprocess the audio file
audio, sample_rate = librosa.load(filename, res_type='kaiser_fast') 
mfccs_features = librosa.feature.mfcc(y=audio, sr=sample_rate, n_mfcc=40)
mfccs_scaled_features = np.mean(mfccs_features.T,axis=0)
#Reshape MFCC feature to 2-D array
mfccs_scaled_features=mfccs_scaled_features.reshape(1,-1)
#predicted_label=model.predict_classes(mfccs_scaled_features)
x_predict=model.predict(mfccs_scaled_features) 
predicted_label=np.argmax(x_predict,axis=1)
print(predicted_label)
prediction_class = labelencoder.inverse_transform(predicted_label) 
print(prediction_class)
# Out:
# 1/1 [==============================] - 0s 16ms/step
# [9]
# ['street_music']

# %%
ipd.Audio(filename)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
